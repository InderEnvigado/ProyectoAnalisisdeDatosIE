# %%
##Conectar con el drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
##cargamos librerias
import pandas as pd
import numpy as np

##establecemos ruta del archivo con los datos
file_INSCRITOSIE='/content/drive/MyDrive/Base de Datos/Informe_de_inscritos.xlsx'
INSCRITOSIE=pd.read_excel(file_INSCRITOSIE)

# %% [markdown]
# **Exploración de datos**

# %%
#consultamos los datos del dataframe
INSCRITOSIE
# Out:
#             fecha  Inscripcion  \
# 0      2018-01-17        89537
# 1      2018-01-17        89531
# 2      2018-01-18        89556
# 3      2018-01-18        89584
# 4      2018-01-18        89685
# ...           ...          ...
# 151403 2020-01-28        45315
# 151404 2021-04-12        47115
# 151405 2022-01-20        50017
# 151406 2022-03-31         2487
# 151407 2023-04-25        47850
#
#                                                  Servicio  \
# 0                                       GIMNASIA INFANTIL
# 1                                                NATACIÓN
# 2                                                NATACIÓN
# 3                                                NATACIÓN
# 4                                                NATACIÓN
# ...                                                   ...
# 151403  MUSICOTERAPIA                                 ...
# 151404  HIDROAERÓBICOS                                ...
# 151405  HIDROAERÓBICOS                                ...
# 151406                               NATACIÓN LAS COMETAS
# 151407  PP ZONA 6
#
#                                                     Nivel  \
# 0       INICIACIÓN 2 (8-12)                           ...
# 1       CALAMARES                                     ...
# 2       III (6-8) AÑOS                                ...
# 3       I ADULTOS                                     ...
# 4       FORMATIVO AVANZADO ADULTOS                    ...
# ...                                                   ...
# 151403  INSCRIPCIÓN                                   ...
# 151404  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151405  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151406  CALAMARES                                     ...
# 151407  LUDOTECA                                      ...
#
#                                       nom_barrio  edad     Género  \
# 0                                            NaN     0   FEMENINO
# 1                                            NaN     0   FEMENINO
# 2                                            NaN     0  MASCULINO
# 3                                            NaN     0  MASCULINO
# 4                                            NaN     0   FEMENINO
# ...                                          ...   ...        ...
# 151403                                       NaN   102  MASCULINO
# 151404       CENTRO                                125   FEMENINO
# 151405                                       NaN   125   FEMENINO
# 151406                                       NaN   125   FEMENINO
# 151407  SAN RAFAEL                                 125   FEMENINO
#
#                                                     etnia  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404  Mestiza                                       ...
# 151405                                                NaN
# 151406                                                NaN
# 151407                     Afrocolombiana
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                          No Aplica
# 151405                                                NaN
# 151406                                                NaN
# 151407  Desplazado                                    ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 2       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       PISCINA POLIDEPORTIVO SUR                     ...  ...
# ...                                                   ...  ...
# 151403  PLACA PARQUE RECREATIVO                       ...  ...
# 151404  PISCINA PARQUE RECREATIVO                     ...  ...
# 151405  PARQUE RECREATIVO                             ...  ...
# 151406  PISCINA LAS COMETAS                           ...  ...
# 151407  LUDOTECA LA MINA                              ...  ...
#
#                                    eps  estrato  \
# 0                                  NaN      NaN
# 1                                  NaN      NaN
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 151403                             NaN      NaN
# 151404  Nueva EPS S.A.                        2
# 151405  Sura EPS                            NaN
# 151406                             NaN      NaN
# 151407  SAVIA SALUD EPS                       1
#
#                                     cod_ciu  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 151403                                  NaN
# 151404  ENVIGADO
# 151405                                  NaN
# 151406                                  NaN
# 151407  ENVIGADO
#
#                                   tipo_documento  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 151403                                       NaN
# 151404  Cédula de Ciudadanía
# 151405  Cédula de Ciudadanía
# 151406  Registro Civil
# 151407  Cédula de Ciudadanía
#
#                                       nacimiento     rh  \
# 0                                            NaN    NaN
# 1                                            NaN    NaN
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 151403                                       NaN    NaN
# 151404  CISNEROS                                  A-
# 151405                                       NaN    NaN
# 151406                                       NaN    NaN
# 151407                                       NaN  O+
#
#                                              nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                                NaN
# 151405                                                NaN
# 151406                                                NaN
# 151407  COLOMBIA                                      ...
#
#                                      escolaridad diversidad  \
# 0                                            NaN  No Aplica
# 1                                            NaN  No Aplica
# 2                                            NaN  No Aplica
# 3                                            NaN  No Aplica
# 4                                            NaN  No Aplica
# ...                                          ...        ...
# 151403                                       NaN  No Aplica
# 151404  BÁSICA SECUNDARIA                         No Aplica
# 151405                                       NaN  No Aplica
# 151406                                       NaN  No Aplica
# 151407  BÁSICA PRIMARIA                           No Aplica
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 3       MUNICIPIO DE ENVIGADO 100%                    ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 151403  MUSICOTERAPIA-                                ...
# 151404  NO APLICA                                     ...
# 151405  NO APLICA                                     ...
# 151406  SISBEN 2                                      ...
# 151407  PP                                            ...
#
# [151408 rows x 24 columns]

# %%
# consultamos las columnas que tiene el dataframe
INSCRITOSIE.columns
# Out:
# Index(['fecha', 'Inscripcion', 'Servicio', 'Nivel', 'nom_barrio', 'edad',
#        'Género', 'etnia', 'Poblacion', 'Escenario', 'instructor', 'curso',
#        'zona', 'fecha_nacimiento', 'eps', 'estrato', 'cod_ciu',
#        'tipo_documento', 'nacimiento', 'rh', 'nacionalidad', 'escolaridad',
#        'diversidad', 'Población'],
#       dtype='object')

# %%
## comando describe para validar estadisticos descriptivos basicos
INSCRITOSIE.describe()
# Out:
#                                fecha   Inscripcion           edad  \
# count                         151408  1.514080e+05  151408.000000
# mean   2022-02-13 23:51:41.257529344  5.862324e+04      31.393011
# min              2018-01-17 00:00:00  1.810000e+02     -75.000000
# 25%              2020-07-16 00:00:00  3.278775e+04      12.000000
# 50%              2022-05-03 00:00:00  5.311100e+04      19.000000
# 75%              2024-01-26 00:00:00  8.206325e+04      56.000000
# max              2025-03-18 00:00:00  2.018045e+07     125.000000
# std                              NaN  1.592314e+05      24.087734
#
#               curso               fecha_nacimiento
# count  1.514080e+05                         146469
# mean   2.021791e+07  1992-04-06 20:24:17.313151616
# min    2.018000e+07            1900-01-01 00:00:00
# 25%    2.020048e+07            1967-12-28 00:00:00
# 50%    2.022058e+07            2004-12-17 00:00:00
# 75%    2.024001e+07            2012-07-13 00:00:00
# max    2.025121e+07            2099-09-10 00:00:00
# std    2.133154e+04                            NaN

# %%
#consultar el tipo de datos
print(INSCRITOSIE.dtypes)
# Out:
# fecha               datetime64[ns]
# Inscripcion                  int64
# Servicio                    object
# Nivel                       object
# nom_barrio                  object
# edad                         int64
# Género                      object
# etnia                       object
# Poblacion                   object
# Escenario                   object
# instructor                  object
# curso                        int64
# zona                        object
# fecha_nacimiento    datetime64[ns]
# eps                         object
# estrato                     object
# cod_ciu                     object
# tipo_documento              object
# nacimiento                  object
# rh                          object
# nacionalidad                object
# escolaridad                 object
# diversidad                  object
# Población                   object
# dtype: object

# %%
# Validar nulos
INSCRITOSIE.isnull().sum()
# Out:
# fecha                    0
# Inscripcion              0
# Servicio                 0
# Nivel                    0
# nom_barrio           21568
# edad                     0
# Género                   0
# etnia                15146
# Poblacion            15209
# Escenario                0
# instructor               0
# curso                    0
# zona                 27125
# fecha_nacimiento      4939
# eps                  20365
# estrato              17651
# cod_ciu              20566
# tipo_documento       19140
# nacimiento          119667
# rh                   17571
# nacionalidad         29279
# escolaridad          19380
# diversidad            1203
# Población                0
# dtype: int64

# %%
##Descripción de las columnas
INSCRITOSIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151408 entries, 0 to 151407
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   fecha             151408 non-null  datetime64[ns]
#  1   Inscripcion       151408 non-null  int64
#  2   Servicio          151408 non-null  object
#  3   Nivel             151408 non-null  object
#  4   nom_barrio        129840 non-null  object
#  5   edad              151408 non-null  int64
#  6   Género            151408 non-null  object
#  7   etnia             136262 non-null  object
#  8   Poblacion         136199 non-null  object
#  9   Escenario         151408 non-null  object
#  10  instructor        151408 non-null  object
#  11  curso             151408 non-null  int64
#  12  zona              124283 non-null  object
#  13  fecha_nacimiento  146469 non-null  datetime64[ns]
#  14  eps               131043 non-null  object
#  15  estrato           133757 non-null  object
#  16  cod_ciu           130842 non-null  object
#  17  tipo_documento    132268 non-null  object
#  18  nacimiento        31741 non-null   object
#  19  rh                133837 non-null  object
#  20  nacionalidad      122129 non-null  object
#  21  escolaridad       132028 non-null  object
#  22  diversidad        150205 non-null  object
#  23  Población         151408 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(19)
# memory usage: 27.7+ MB

# %%
## Identificar valores nulos
INSCRITOSIE.isnull()
# Out:
#         fecha  Inscripcion  Servicio  Nivel  nom_barrio   edad  Género  etnia  \
# 0       False        False     False  False        True  False   False   True
# 1       False        False     False  False        True  False   False   True
# 2       False        False     False  False        True  False   False   True
# 3       False        False     False  False        True  False   False   True
# 4       False        False     False  False        True  False   False   True
# ...       ...          ...       ...    ...         ...    ...     ...    ...
# 151403  False        False     False  False        True  False   False   True
# 151404  False        False     False  False       False  False   False  False
# 151405  False        False     False  False        True  False   False   True
# 151406  False        False     False  False        True  False   False   True
# 151407  False        False     False  False       False  False   False  False
#
#         Poblacion  Escenario  ...    eps  estrato  cod_ciu  tipo_documento  \
# 0            True      False  ...   True     True     True            True
# 1            True      False  ...   True     True     True            True
# 2            True      False  ...   True     True     True            True
# 3            True      False  ...   True     True     True            True
# 4            True      False  ...   True     True     True            True
# ...           ...        ...  ...    ...      ...      ...             ...
# 151403       True      False  ...   True     True     True            True
# 151404      False      False  ...  False    False    False           False
# 151405       True      False  ...  False     True     True           False
# 151406       True      False  ...   True     True     True           False
# 151407      False      False  ...  False    False    False           False
#
#         nacimiento     rh  nacionalidad  escolaridad  diversidad  Población
# 0             True   True          True         True       False      False
# 1             True   True          True         True       False      False
# 2             True   True          True         True       False      False
# 3             True   True          True         True       False      False
# 4             True   True          True         True       False      False
# ...            ...    ...           ...          ...         ...        ...
# 151403        True   True          True         True       False      False
# 151404       False  False          True        False       False      False
# 151405        True   True          True         True       False      False
# 151406        True   True          True         True       False      False
# 151407        True  False         False        False       False      False
#
# [151408 rows x 24 columns]

# %%
# Mostramos las primeras filas del dataframe
INSCRITOSIE.head()
# Out:
#        fecha  Inscripcion           Servicio  \
# 0 2018-01-17        89537  GIMNASIA INFANTIL
# 1 2018-01-17        89531           NATACIÓN
# 2 2018-01-18        89556           NATACIÓN
# 3 2018-01-18        89584           NATACIÓN
# 4 2018-01-18        89685           NATACIÓN
#
#                                                Nivel nom_barrio  edad  \
# 0  INICIACIÓN 2 (8-12)                           ...        NaN     0
# 1  CALAMARES                                     ...        NaN     0
# 2  III (6-8) AÑOS                                ...        NaN     0
# 3  I ADULTOS                                     ...        NaN     0
# 4  FORMATIVO AVANZADO ADULTOS                    ...        NaN     0
#
#       Género etnia Poblacion  \
# 0   FEMENINO   NaN       NaN
# 1   FEMENINO   NaN       NaN
# 2  MASCULINO   NaN       NaN
# 3  MASCULINO   NaN       NaN
# 4   FEMENINO   NaN       NaN
#
#                                            Escenario  ...  eps  estrato  \
# 0  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...  NaN      NaN
# 1  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 2  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 3  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 4  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
#
#   cod_ciu tipo_documento nacimiento   rh nacionalidad escolaridad diversidad  \
# 0     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 1     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 2     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 3     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 4     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
#
#                                            Población
# 0  NO APLICA                                     ...
# 1  NO APLICA                                     ...
# 2  INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 3  MUNICIPIO DE ENVIGADO 100%                    ...
# 4  NO APLICA                                     ...
#
# [5 rows x 24 columns]

# %%
# verificar valores únicos en Barrio
print(INSCRITOSIE['nom_barrio'].unique())
# Out:
# [nan 'LA PAZ                                  '
#  'LA MINA                                 '
#  'LOMA DE LAS BRUJAS                      '
#  'SAN RAFAEL                              '
#  'NO APLICA                               '
#  'LAS VEGAS                               '
#  'OTRO                                    '
#  'ZUÑIGA                                  '
#  'MESA                             '
#  'EL TRIANÓN                              '
#  'CENTRO                             '
#  'SAN MARCOS                              '
#  'URIBE ANGEL                             '
#  'ALCALÁ                                  '
#  'EL DORADO                               '
#  'SAN JOSÉ                                '
#  'PRIMAVERA                               '
#  'LOMA DEL BARRO                          '
#  'LA SEBASTIANA                           '
#  'LOS NARANJOS                            '
#  'LAS ORQUÍDEAS                           '
#  'ALTO DE MISAEL                          '
#  'LAS CASITAS                             '
#  'PONTEVEDRA                              '
#  'VEREDA PERICO                           '
#  'EL OBRERO                               '
#  'VEREDA LAS PALMAS                       '
#  'EL CHINGUÍ                              '
#  'EL PORTAL                               '
#  'LA MAGNOLIA                             '
#  'EL CHOCHO                               '
#  'EL SALADO                               '
#  'JARDINES                                '
#  'LA INMACULADA                           '
#  'VEREDA PANTANILLO                       '
#  'VEREDA EL VALLANO                       '
#  'LAS ANTILLAS                            '
#  'LA PRADERA                              '
#  'LAS FLORES                              '
#  'BUCAREST                                '
#  'LOMA EL ATRAVESADO                      '
#  'MILÁN - VALLEJUELOS                     '
#  'EL ESMERALDAL                           '
#  'VEREDA EL ESCOBERO                      '
#  'BOSQUES DE ZUÑIGA                       '
#  'VILLAGRANDE                             '
#  'VEREDA SANTA CATALINA                   ']

# %%
# Cuantas filas y columnas tiene nuestro dataframe
INSCRITOSIE.shape
# Out:
# (151408, 24)

# %%
# libreria skimpy permite realizar estadisticos descriptivos de variables categóricas
# !pip install skimpy
from skimpy import skim

skim(INSCRITOSIE)
# Out:
# Requirement already satisfied: skimpy in /usr/local/lib/python3.11/dist-packages (0.0.18)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from skimpy) (8.1.8)
# Requirement already satisfied: ipykernel>=6.29.5 in /usr/local/lib/python3.11/dist-packages (from skimpy) (6.29.5)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.0.2)
# Requirement already satisfied: pandas-stubs>=2.2.2.240807 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.2.2.240909)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.2.3)
# Requirement already satisfied: polars>=1.17.1 in /usr/local/lib/python3.11/dist-packages (from skimpy) (1.21.0)
# Requirement already satisfied: pygments>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from skimpy) (2.18.0)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.11/dist-packages (from skimpy) (13.9.4)
# Requirement already satisfied: typeguard>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from skimpy) (4.4.2)
# Requirement already satisfied: pyarrow>=17.0.0 in /usr/local/lib/python3.11/dist-packages (from skimpy) (18.1.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=6.29.5->skimpy) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->skimpy) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->skimpy) (2025.1)
# Requirement already satisfied: types-pytz>=2022.1.1 in /usr/local/lib/python3.11/dist-packages (from pandas-stubs>=2.2.2.240807->skimpy) (2025.1.0.20250318)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->skimpy) (3.0.0)
# Requirement already satisfied: typing_extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from typeguard>=4.4.1->skimpy) (4.12.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (3.0.50)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->skimpy) (4.3.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->skimpy) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->skimpy) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.13)
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 151408 │ │ string      │ 13    │                                                          │
# │ │ Number of columns │ 18     │ │ int64       │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ datetime64  │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column     ┃ NA ┃ NA % ┃ mean     ┃ sd     ┃ p0       ┃ p25      ┃ p50      ┃ p75      ┃ p100     ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━┩  │
# │ │ Inscripcio │  0 │    0 │    58620 │ 159200 │      181 │    32790 │    53110 │    82060 │ 20180000 │   █    │  │
# │ │ n          │    │      │          │        │          │          │          │          │          │        │  │
# │ │ edad       │  0 │    0 │    31.39 │  24.09 │      -75 │       12 │       19 │       56 │      125 │   █▃▃  │  │
# │ │ curso      │  0 │    0 │ 20220000 │  21330 │ 20180000 │ 20200000 │ 20220000 │ 20240000 │ 20250000 │ ▆▃▅▅▅█ │  │
# │ └────────────┴────┴──────┴──────────┴────────┴──────────┴──────────┴──────────┴──────────┴──────────┴────────┘  │
# │                                                    datetime                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓  │
# │ ┃ column                 ┃ NA     ┃ NA %                    ┃ first          ┃ last           ┃ frequency    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩  │
# │ │ fecha                  │      0 │                       0 │   2018-01-17   │   2025-03-18   │ None         │  │
# │ │ fecha_nacimiento       │   4939 │       3.262046919581528 │   1900-01-01   │   2099-09-10   │ None         │  │
# │ └────────────────────────┴────────┴─────────────────────────┴────────────────┴────────────────┴──────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃          ┃       ┃          ┃          ┃          ┃          ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column   ┃ NA    ┃ NA %     ┃ shortest ┃ longest  ┃ min      ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ Servicio │     0 │        0 │ JUDO     │ TENIS DE │ ACTIVIDA │ YOGA      │     45.4 │        32 │  4909666 │  │
# │ │          │       │          │          │ CAMPO    │ DES      │           │          │           │          │  │
# │ │          │       │          │          │          │ ACUATICA │           │          │           │          │  │
# │ │          │       │          │          │          │ S - ALTO │           │          │           │          │  │
# │ │          │       │          │          │          │ DE LOS   │           │          │           │          │  │
# │ │          │       │          │          │          │ SUEÑOS   │           │          │           │          │  │
# │ │ nom_barr │ 21568 │ 14.24495 │ MESA     │ LA PAZ   │ ALCALÁ   │ ZUÑIGA    │     39.7 │        27 │  4140273 │  │
# │ │ io       │       │ 40314910 │          │          │          │           │          │           │          │  │
# │ │          │       │       71 │          │          │          │           │          │           │          │  │
# │ │ Género   │     0 │        0 │ FEMENINO │ NO       │ FEMENINO │ NO        │      8.4 │         1 │   152316 │  │
# │ │          │       │          │          │ REGISTRA │          │ REGISTRA  │          │           │          │  │
# │ │ etnia    │ 15146 │ 10.00343 │ Rom      │ Mestiza  │ Afrocolo │ Rom       │       43 │        33 │  5024427 │  │
# │ │          │       │ 44288280 │          │          │ mbiana   │           │          │           │          │  │
# │ │          │       │       67 │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ Poblacio │ 15209 │ 10.04504 │ Migrante │ Víctima  │ Campesin │ Víctima   │     33.2 │        16 │  2449241 │  │
# │ │ n        │       │ 38550142 │          │ del      │ o        │ del       │          │           │          │  │
# │ │          │       │       65 │          │ conflict │          │ conflicto │          │           │          │  │
# │ │          │       │          │          │ o armado │          │ armado    │          │           │          │  │
# │ │ Escenari │     0 │        0 │ SALON DE │ SALON DE │  CEC     │ ZUÑIGA    │       50 │        33 │  5039549 │  │
# │ │ o        │       │          │ GIMNASIA │ GIMNASIA │ CASA     │           │          │           │          │  │
# │ │          │       │          │ INFANTIL │ INFANTIL │ LINARES  │           │          │           │          │  │
# │ │          │       │          │ POLIDEPO │ POLIDEPO │          │           │          │           │          │  │
# │ │          │       │          │ RTIVO    │ RTIVO    │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ instruct │     0 │        0 │ MARIA    │ _x0002_B │   JONATH │ _x0002_BE │       80 │        60 │  9089674 │  │
# │ │ or       │       │          │ FERNANDA │ ETSY     │ AN       │ TSY       │          │           │          │  │
# │ │          │       │          │ OSPINA   │ JULIETH  │ GUEVARA- │ JULIETH   │          │           │          │  │
# │ │          │       │          │          │ MURIEL   │ LAURA P  │ MURIEL    │          │           │          │  │
# │ │          │       │          │          │ MUNERA   │          │ MUNERA    │          │           │          │  │
# │ │ eps      │ 20365 │ 13.45041 │ SURA     │ SURA     │          │ VIVE      │       30 │        19 │  2916026 │  │
# │ │          │       │ 21314593 │          │          │          │ PROTECCIÓ │          │           │          │  │
# │ │          │       │       68 │          │          │          │ N         │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ cod_ciu  │ 20566 │ 13.58316 │ ENVIGADO │ ENVIGADO │          │ ZARAGOZA  │       35 │        24 │  3673692 │  │
# │ │          │       │ 60150058 │          │          │          │           │          │           │          │  │
# │ │          │       │       12 │          │          │          │           │          │           │          │  │
# │ │ tipo_doc │ 19140 │ 12.64133 │ No       │ No       │ Cédula   │ Tipo      │       40 │        20 │  3102679 │  │
# │ │ umento   │       │ 99556166 │ Aplica   │ Aplica   │ de       │ documento │          │           │          │  │
# │ │          │       │       12 │          │          │ Ciudadan │ Extranjer │          │           │          │  │
# │ │          │       │          │          │          │ ía       │ o         │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │ rh       │ 17571 │ 11.60506 │ B+       │ B+       │          │ o-        │        5 │       3.6 │   539495 │  │
# │ │          │       │ 71034555 │          │          │          │           │          │           │          │  │
# │ │          │       │       64 │          │          │          │           │          │           │          │  │
# │ │ diversid │  1203 │ 0.794541 │ No       │ Bisexual │ Bisexual │ Trans     │     10.4 │         2 │   307875 │  │
# │ │ ad       │       │ 90003170 │ Aplica   │          │          │           │          │           │          │  │
# │ │          │       │       24 │          │          │          │           │          │           │          │  │
# │ │ Població │     0 │        0 │ NO       │ NO       │ ALTO     │ VICTIMA   │       50 │        44 │  6722583 │  │
# │ │ n        │       │          │ APLICA   │ APLICA   │ RENDIMIE │           │          │           │          │  │
# │ │          │       │          │          │          │ NTO      │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ │          │       │          │          │          │          │           │          │           │          │  │
# │ └──────────┴───────┴──────────┴──────────┴──────────┴──────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
## comando TAIL para visualizar ultimos registros
INSCRITOSIE.tail(20)
# Out:
#             fecha  Inscripcion  \
# 151388 2020-01-21        44514
# 151389 2018-01-19        33869
# 151390 2018-07-23        37046
# 151391 2019-01-21        40028
# 151392 2019-07-19        42704
# 151393 2024-05-02        69389
# 151394 2018-01-19        33884
# 151395 2018-07-23        37054
# 151396 2019-01-21        39998
# 151397 2019-07-19        42663
# 151398 2021-11-17        19319
# 151399 2018-09-28        99241
# 151400 2018-07-16        36495
# 151401 2019-01-21        40068
# 151402 2019-07-17        42382
# 151403 2020-01-28        45315
# 151404 2021-04-12        47115
# 151405 2022-01-20        50017
# 151406 2022-03-31         2487
# 151407 2023-04-25        47850
#
#                                                  Servicio  \
# 151388  MUSICOTERAPIA                                 ...
# 151389  MUSICOTERAPIA                                 ...
# 151390  MUSICOTERAPIA                                 ...
# 151391  MUSICOTERAPIA                                 ...
# 151392  MUSICOTERAPIA                                 ...
# 151393  PP ZONA 2
# 151394  MUSICOTERAPIA                                 ...
# 151395  MUSICOTERAPIA                                 ...
# 151396  MUSICOTERAPIA                                 ...
# 151397  MUSICOTERAPIA                                 ...
# 151398  PP ZONA 9
# 151399  PP ZONA 8
# 151400  MUSICOTERAPIA                                 ...
# 151401  MUSICOTERAPIA                                 ...
# 151402  MUSICOTERAPIA                                 ...
# 151403  MUSICOTERAPIA                                 ...
# 151404  HIDROAERÓBICOS                                ...
# 151405  HIDROAERÓBICOS                                ...
# 151406                               NATACIÓN LAS COMETAS
# 151407  PP ZONA 6
#
#                                                     Nivel  \
# 151388  INSCRIPCIÓN                                   ...
# 151389  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151390  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151391  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151392  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151393  MUSICOTERAPIA                                 ...
# 151394  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151395  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151396  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151397  INSCRIPCIÓN AMIGOS FELICES                    ...
# 151398  MANTENIMIENTO FISICO                          ...
# 151399                                            AJEDREZ
# 151400  INSCRIPCIÓN                                   ...
# 151401  INSCRIPCIÓN                                   ...
# 151402  INSCRIPCIÓN                                   ...
# 151403  INSCRIPCIÓN                                   ...
# 151404  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151405  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151406  CALAMARES                                     ...
# 151407  LUDOTECA                                      ...
#
#                                       nom_barrio  edad     Género  \
# 151388                                       NaN    98  MASCULINO
# 151389                                       NaN    98   FEMENINO
# 151390                                       NaN    98   FEMENINO
# 151391                                       NaN    98   FEMENINO
# 151392                                       NaN    98   FEMENINO
# 151393  EL PORTAL                                   99   FEMENINO
# 151394                                       NaN   100   FEMENINO
# 151395                                       NaN   100   FEMENINO
# 151396                                       NaN   100   FEMENINO
# 151397                                       NaN   100   FEMENINO
# 151398  LA MAGNOLIA                                100   FEMENINO
# 151399                                       NaN   101   FEMENINO
# 151400                                       NaN   102  MASCULINO
# 151401                                       NaN   102  MASCULINO
# 151402                                       NaN   102  MASCULINO
# 151403                                       NaN   102  MASCULINO
# 151404       CENTRO                                125   FEMENINO
# 151405                                       NaN   125   FEMENINO
# 151406                                       NaN   125   FEMENINO
# 151407  SAN RAFAEL                                 125   FEMENINO
#
#                                                     etnia  \
# 151388                                                NaN
# 151389  Mestiza                                       ...
# 151390  Mestiza                                       ...
# 151391  Mestiza                                       ...
# 151392  Mestiza                                       ...
# 151393  Mestiza                                       ...
# 151394                                                NaN
# 151395                                                NaN
# 151396                                                NaN
# 151397                                                NaN
# 151398  Otro                                          ...
# 151399  Mestiza                                       ...
# 151400                                                NaN
# 151401                                                NaN
# 151402                                                NaN
# 151403                                                NaN
# 151404  Mestiza                                       ...
# 151405                                                NaN
# 151406                                                NaN
# 151407                     Afrocolombiana
#
#                                                 Poblacion  \
# 151388                                                NaN
# 151389                                          No Aplica
# 151390                                          No Aplica
# 151391                                          No Aplica
# 151392                                          No Aplica
# 151393                                          No Aplica
# 151394                                                NaN
# 151395                                                NaN
# 151396                                                NaN
# 151397                                                NaN
# 151398  Ninguna de las anteriores                     ...
# 151399  Persona en condición de discapacidad
# 151400                                                NaN
# 151401                                                NaN
# 151402                                                NaN
# 151403                                                NaN
# 151404                                          No Aplica
# 151405                                                NaN
# 151406                                                NaN
# 151407  Desplazado                                    ...
#
#                                                 Escenario  ...  \
# 151388  PLACA PARQUE RECREATIVO                       ...  ...
# 151389  PLACA PARQUE RECREATIVO                       ...  ...
# 151390  PLACA PARQUE RECREATIVO                       ...  ...
# 151391  PLACA PARQUE RECREATIVO                       ...  ...
# 151392  PARQUE RECREATIVO                             ...  ...
# 151393  HOGAR LUZ DE MARIA                            ...  ...
# 151394  PLACA PARQUE RECREATIVO                       ...  ...
# 151395  PLACA PARQUE RECREATIVO                       ...  ...
# 151396  PLACA PARQUE RECREATIVO                       ...  ...
# 151397  PARQUE RECREATIVO                             ...  ...
# 151398  HOGAR GERIATRICO  REVIVIR                     ...  ...
# 151399  CENTRO GERONTOLÓGICO EL REFUGIO  (ZONA 8)     ...  ...
# 151400  PLACA PARQUE RECREATIVO                       ...  ...
# 151401  PLACA PARQUE RECREATIVO                       ...  ...
# 151402  PARQUE RECREATIVO                             ...  ...
# 151403  PLACA PARQUE RECREATIVO                       ...  ...
# 151404  PISCINA PARQUE RECREATIVO                     ...  ...
# 151405  PARQUE RECREATIVO                             ...  ...
# 151406  PISCINA LAS COMETAS                           ...  ...
# 151407  LUDOTECA LA MINA                              ...  ...
#
#                                    eps  estrato  \
# 151388                             NaN      NaN
# 151389                             NaN      NaN
# 151390                             NaN      NaN
# 151391                             NaN      NaN
# 151392                             NaN      NaN
# 151393  NUEVA EPS S.A.                        5
# 151394                             NaN      NaN
# 151395                             NaN      NaN
# 151396                             NaN      NaN
# 151397                             NaN      NaN
# 151398  SISBÉN                                5
# 151399                             NaN        3
# 151400                             NaN      NaN
# 151401                             NaN      NaN
# 151402                             NaN      NaN
# 151403                             NaN      NaN
# 151404  Nueva EPS S.A.                        2
# 151405  Sura EPS                            NaN
# 151406                             NaN      NaN
# 151407  SAVIA SALUD EPS                       1
#
#                                     cod_ciu  \
# 151388                                  NaN
# 151389                                  NaN
# 151390                                  NaN
# 151391                                  NaN
# 151392                                  NaN
# 151393  ENVIGADO
# 151394                                  NaN
# 151395                                  NaN
# 151396                                  NaN
# 151397                                  NaN
# 151398  ENVIGADO
# 151399                                  NaN
# 151400                                  NaN
# 151401                                  NaN
# 151402                                  NaN
# 151403                                  NaN
# 151404  ENVIGADO
# 151405                                  NaN
# 151406                                  NaN
# 151407  ENVIGADO
#
#                                   tipo_documento  \
# 151388                                       NaN
# 151389                                       NaN
# 151390                                       NaN
# 151391                                       NaN
# 151392                                       NaN
# 151393  Cédula de Ciudadanía
# 151394                                       NaN
# 151395                                       NaN
# 151396                                       NaN
# 151397                                       NaN
# 151398  Cédula de Ciudadanía
# 151399                                       NaN
# 151400                                       NaN
# 151401                                       NaN
# 151402                                       NaN
# 151403                                       NaN
# 151404  Cédula de Ciudadanía
# 151405  Cédula de Ciudadanía
# 151406  Registro Civil
# 151407  Cédula de Ciudadanía
#
#                                       nacimiento     rh  \
# 151388                                       NaN    NaN
# 151389                                       NaN    NaN
# 151390                                       NaN    NaN
# 151391                                       NaN    NaN
# 151392                                       NaN    NaN
# 151393                                       NaN  O+
# 151394                                       NaN    NaN
# 151395                                       NaN    NaN
# 151396                                       NaN    NaN
# 151397                                       NaN    NaN
# 151398                                       NaN  B+
# 151399                                       NaN
# 151400                                       NaN    NaN
# 151401                                       NaN    NaN
# 151402                                       NaN    NaN
# 151403                                       NaN    NaN
# 151404  CISNEROS                                  A-
# 151405                                       NaN    NaN
# 151406                                       NaN    NaN
# 151407                                       NaN  O+
#
#                                              nacionalidad  \
# 151388                                                NaN
# 151389                                                NaN
# 151390                                                NaN
# 151391                                                NaN
# 151392                                                NaN
# 151393  COLOMBIA                                      ...
# 151394                                                NaN
# 151395                                                NaN
# 151396                                                NaN
# 151397                                                NaN
# 151398  COLOMBIA                                      ...
# 151399                                                NaN
# 151400                                                NaN
# 151401                                                NaN
# 151402                                                NaN
# 151403                                                NaN
# 151404                                                NaN
# 151405                                                NaN
# 151406                                                NaN
# 151407  COLOMBIA                                      ...
#
#                                      escolaridad    diversidad  \
# 151388                                       NaN     No Aplica
# 151389                                       NaN     No Aplica
# 151390                                       NaN     No Aplica
# 151391                                       NaN     No Aplica
# 151392                                       NaN     No Aplica
# 151393  NINGUNO                                   Heterosexual
# 151394                                       NaN     No Aplica
# 151395                                       NaN     No Aplica
# 151396                                       NaN     No Aplica
# 151397                                       NaN     No Aplica
# 151398  NINGUNA DE LAS ANTERIORES                    No Aplica
# 151399                                               No Aplica
# 151400                                       NaN     No Aplica
# 151401                                       NaN     No Aplica
# 151402                                       NaN     No Aplica
# 151403                                       NaN     No Aplica
# 151404  BÁSICA SECUNDARIA                            No Aplica
# 151405                                       NaN     No Aplica
# 151406                                       NaN     No Aplica
# 151407  BÁSICA PRIMARIA                              No Aplica
#
#                                                 Población
# 151388  MUSICOTERAPIA-                                ...
# 151389  MUSICOTERAPIA-                                ...
# 151390  MUSICOTERAPIA-                                ...
# 151391  MUSICOTERAPIA-                                ...
# 151392  MUSICOTERAPIA-                                ...
# 151393  PP                                            ...
# 151394  MUSICOTERAPIA-                                ...
# 151395  MUSICOTERAPIA-                                ...
# 151396  MUSICOTERAPIA-                                ...
# 151397  MUSICOTERAPIA-                                ...
# 151398  PP                                            ...
# 151399  PP                                            ...
# 151400  MUSICOTERAPIA-                                ...
# 151401  MUSICOTERAPIA-                                ...
# 151402  MUSICOTERAPIA-                                ...
# 151403  MUSICOTERAPIA-                                ...
# 151404  NO APLICA                                     ...
# 151405  NO APLICA                                     ...
# 151406  SISBEN 2                                      ...
# 151407  PP                                            ...
#
# [20 rows x 24 columns]

# %%
#muestra los primeros 20 registros
INSCRITOSIE.head(20)
# Out:
#         fecha  Inscripcion                                           Servicio  \
# 0  2018-01-17        89537                                  GIMNASIA INFANTIL
# 1  2018-01-17        89531                                           NATACIÓN
# 2  2018-01-18        89556                                           NATACIÓN
# 3  2018-01-18        89584                                           NATACIÓN
# 4  2018-01-18        89685                                           NATACIÓN
# 5  2018-01-18        89559                                           NATACIÓN
# 6  2018-01-18        89560                                           NATACIÓN
# 7  2018-01-18        89669  TENIS DE CAMPO                                ...
# 8  2018-01-18        89615                                           NATACIÓN
# 9  2018-01-18        89657                                           NATACIÓN
# 10 2018-01-18        89677                                  GIMNASIA INFANTIL
# 11 2018-01-18        89544  TENIS DE CAMPO                                ...
# 12 2018-01-18        89587                                           NATACIÓN
# 13 2018-01-18        89650                                           NATACIÓN
# 14 2018-01-18        89601                                           NATACIÓN
# 15 2018-01-19        89766                                           NATACIÓN
# 16 2018-01-19        89702                                           NATACIÓN
# 17 2018-01-19        89701                                           NATACIÓN
# 18 2018-01-19        89756                                           NATACIÓN
# 19 2018-01-19        89754                                           NATACIÓN
#
#                                                 Nivel nom_barrio  edad  \
# 0   INICIACIÓN 2 (8-12)                           ...        NaN     0
# 1   CALAMARES                                     ...        NaN     0
# 2   III (6-8) AÑOS                                ...        NaN     0
# 3   I ADULTOS                                     ...        NaN     0
# 4   FORMATIVO AVANZADO ADULTOS                    ...        NaN     0
# 5   III ADULTOS                                   ...        NaN     0
# 6   III ADULTOS                                   ...        NaN     0
# 7   PRINCIPIANTES ADULTOS (18-en adelate          ...        NaN     0
# 8   I (9-12) AÑOS                                 ...        NaN     0
# 9   II (6-8) AÑOS                                 ...        NaN     0
# 10  NIVEL 1 (6-12 AÑOS)                           ...        NaN     0
# 11  INICIADOS ADULTOS (18 en adelante)            ...        NaN     0
# 12  I ADULTOS                                     ...        NaN     0
# 13  I ADULTOS                                     ...        NaN     0
# 14  I (9-12) AÑOS                                 ...        NaN     0
# 15  I ADULTOS                                     ...        NaN     0
# 16  III ADULTOS                                   ...        NaN     0
# 17  VII ADULTOS                                   ...        NaN     0
# 18  I (6-8) AÑOS                                  ...        NaN     0
# 19  IV NIÑOS                                      ...        NaN     0
#
#        Género                                              etnia  \
# 0    FEMENINO                                                NaN
# 1    FEMENINO                                                NaN
# 2   MASCULINO                                                NaN
# 3   MASCULINO                                                NaN
# 4    FEMENINO                                                NaN
# 5    FEMENINO                                                NaN
# 6   MASCULINO                                                NaN
# 7   MASCULINO                                                NaN
# 8   MASCULINO                                                NaN
# 9    FEMENINO                                                NaN
# 10   FEMENINO                                                NaN
# 11   FEMENINO                                                NaN
# 12   FEMENINO                                                NaN
# 13  MASCULINO                                                NaN
# 14  MASCULINO                                                NaN
# 15   FEMENINO                                                NaN
# 16   FEMENINO                                                NaN
# 17   FEMENINO                                                NaN
# 18   FEMENINO                                                NaN
# 19  MASCULINO  Mestiza                                       ...
#
#                                             Poblacion  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Víctima del conflicto armado                  ...
#
#                                             Escenario  ...  eps  estrato  \
# 0   SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...  NaN      NaN
# 1   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 2   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 3   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 4   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 5   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 6   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 7   CANCHA TENIS POLI-NRO 3                       ...  ...  NaN      NaN
# 8   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 9   PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 10  SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...  NaN      NaN
# 11  CANCHA TENIS POLI-NRO 3                       ...  ...  NaN      NaN
# 12  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 13  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 14  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 15  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 16  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 17  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 18  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
# 19  PISCINA POLIDEPORTIVO SUR                     ...  ...  NaN      NaN
#
#    cod_ciu tipo_documento nacimiento   rh nacionalidad escolaridad diversidad  \
# 0      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 1      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 2      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 3      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 4      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 5      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 6      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 7      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 8      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 9      NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 10     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 11     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 12     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 13     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 14     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 15     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 16     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 17     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 18     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
# 19     NaN            NaN        NaN  NaN          NaN         NaN  No Aplica
#
#                                             Población
# 0   NO APLICA                                     ...
# 1   NO APLICA                                     ...
# 2   INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 3   MUNICIPIO DE ENVIGADO 100%                    ...
# 4   NO APLICA                                     ...
# 5   NO APLICA                                     ...
# 6   NO APLICA                                     ...
# 7   NO APLICA                                     ...
# 8   NO APLICA                                     ...
# 9   INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 10  NO APLICA                                     ...
# 11  NO APLICA                                     ...
# 12  NO APLICA                                     ...
# 13  NO APLICA                                     ...
# 14  NO APLICA                                     ...
# 15  NO APLICA                                     ...
# 16  NO APLICA                                     ...
# 17  NO APLICA                                     ...
# 18  INCAPACIDAD DE PAGO Y/O CONVENIO 100%         ...
# 19  INCAPACIDAD DE PAGO Y/O CONVENIO 100%         ...
#
# [20 rows x 24 columns]

# %% [markdown]
# **Limpieza de datos**

# %%
##Renombramos las columnas
INSCRITOSIE.rename(columns={"fecha": "fecha_inscripción"})
# Out:
#        fecha_inscripción  Inscripcion  \
# 0             2018-01-17        89537
# 1             2018-01-17        89531
# 2             2018-01-18        89556
# 3             2018-01-18        89584
# 4             2018-01-18        89685
# ...                  ...          ...
# 151403        2020-01-28        45315
# 151404        2021-04-12        47115
# 151405        2022-01-20        50017
# 151406        2022-03-31         2487
# 151407        2023-04-25        47850
#
#                                                  Servicio  \
# 0                                       GIMNASIA INFANTIL
# 1                                                NATACIÓN
# 2                                                NATACIÓN
# 3                                                NATACIÓN
# 4                                                NATACIÓN
# ...                                                   ...
# 151403  MUSICOTERAPIA                                 ...
# 151404  HIDROAERÓBICOS                                ...
# 151405  HIDROAERÓBICOS                                ...
# 151406                               NATACIÓN LAS COMETAS
# 151407  PP ZONA 6
#
#                                                     Nivel  \
# 0       INICIACIÓN 2 (8-12)                           ...
# 1       CALAMARES                                     ...
# 2       III (6-8) AÑOS                                ...
# 3       I ADULTOS                                     ...
# 4       FORMATIVO AVANZADO ADULTOS                    ...
# ...                                                   ...
# 151403  INSCRIPCIÓN                                   ...
# 151404  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151405  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151406  CALAMARES                                     ...
# 151407  LUDOTECA                                      ...
#
#                                       nom_barrio  edad     Género  \
# 0                                            NaN     0   FEMENINO
# 1                                            NaN     0   FEMENINO
# 2                                            NaN     0  MASCULINO
# 3                                            NaN     0  MASCULINO
# 4                                            NaN     0   FEMENINO
# ...                                          ...   ...        ...
# 151403                                       NaN   102  MASCULINO
# 151404       CENTRO                                125   FEMENINO
# 151405                                       NaN   125   FEMENINO
# 151406                                       NaN   125   FEMENINO
# 151407  SAN RAFAEL                                 125   FEMENINO
#
#                                                     etnia  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404  Mestiza                                       ...
# 151405                                                NaN
# 151406                                                NaN
# 151407                     Afrocolombiana
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                          No Aplica
# 151405                                                NaN
# 151406                                                NaN
# 151407  Desplazado                                    ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 2       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       PISCINA POLIDEPORTIVO SUR                     ...  ...
# ...                                                   ...  ...
# 151403  PLACA PARQUE RECREATIVO                       ...  ...
# 151404  PISCINA PARQUE RECREATIVO                     ...  ...
# 151405  PARQUE RECREATIVO                             ...  ...
# 151406  PISCINA LAS COMETAS                           ...  ...
# 151407  LUDOTECA LA MINA                              ...  ...
#
#                                    eps  estrato  \
# 0                                  NaN      NaN
# 1                                  NaN      NaN
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 151403                             NaN      NaN
# 151404  Nueva EPS S.A.                        2
# 151405  Sura EPS                            NaN
# 151406                             NaN      NaN
# 151407  SAVIA SALUD EPS                       1
#
#                                     cod_ciu  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 151403                                  NaN
# 151404  ENVIGADO
# 151405                                  NaN
# 151406                                  NaN
# 151407  ENVIGADO
#
#                                   tipo_documento  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 151403                                       NaN
# 151404  Cédula de Ciudadanía
# 151405  Cédula de Ciudadanía
# 151406  Registro Civil
# 151407  Cédula de Ciudadanía
#
#                                       nacimiento     rh  \
# 0                                            NaN    NaN
# 1                                            NaN    NaN
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 151403                                       NaN    NaN
# 151404  CISNEROS                                  A-
# 151405                                       NaN    NaN
# 151406                                       NaN    NaN
# 151407                                       NaN  O+
#
#                                              nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                                NaN
# 151405                                                NaN
# 151406                                                NaN
# 151407  COLOMBIA                                      ...
#
#                                      escolaridad diversidad  \
# 0                                            NaN  No Aplica
# 1                                            NaN  No Aplica
# 2                                            NaN  No Aplica
# 3                                            NaN  No Aplica
# 4                                            NaN  No Aplica
# ...                                          ...        ...
# 151403                                       NaN  No Aplica
# 151404  BÁSICA SECUNDARIA                         No Aplica
# 151405                                       NaN  No Aplica
# 151406                                       NaN  No Aplica
# 151407  BÁSICA PRIMARIA                           No Aplica
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 3       MUNICIPIO DE ENVIGADO 100%                    ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 151403  MUSICOTERAPIA-                                ...
# 151404  NO APLICA                                     ...
# 151405  NO APLICA                                     ...
# 151406  SISBEN 2                                      ...
# 151407  PP                                            ...
#
# [151408 rows x 24 columns]

# %%
##Renombramos las columnas
INSCRITOSIE = INSCRITOSIE.rename(columns={"Inscripcion": "Nro_inscripcion"})
INSCRITOSIE = INSCRITOSIE.rename(columns={"nom_barrio": "Barrio"})
INSCRITOSIE = INSCRITOSIE.rename(columns={"Servicio": "Disciplina"})
INSCRITOSIE = INSCRITOSIE.rename(columns={"cod_ciu": "Municipio_residencia"})
INSCRITOSIE
# Out:
#             fecha  Nro_inscripcion  \
# 0      2018-01-17            89537
# 1      2018-01-17            89531
# 2      2018-01-18            89556
# 3      2018-01-18            89584
# 4      2018-01-18            89685
# ...           ...              ...
# 151403 2020-01-28            45315
# 151404 2021-04-12            47115
# 151405 2022-01-20            50017
# 151406 2022-03-31             2487
# 151407 2023-04-25            47850
#
#                                                Disciplina  \
# 0                                       GIMNASIA INFANTIL
# 1                                                NATACIÓN
# 2                                                NATACIÓN
# 3                                                NATACIÓN
# 4                                                NATACIÓN
# ...                                                   ...
# 151403  MUSICOTERAPIA                                 ...
# 151404  HIDROAERÓBICOS                                ...
# 151405  HIDROAERÓBICOS                                ...
# 151406                               NATACIÓN LAS COMETAS
# 151407  PP ZONA 6
#
#                                                     Nivel  \
# 0       INICIACIÓN 2 (8-12)                           ...
# 1       CALAMARES                                     ...
# 2       III (6-8) AÑOS                                ...
# 3       I ADULTOS                                     ...
# 4       FORMATIVO AVANZADO ADULTOS                    ...
# ...                                                   ...
# 151403  INSCRIPCIÓN                                   ...
# 151404  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151405  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151406  CALAMARES                                     ...
# 151407  LUDOTECA                                      ...
#
#                                           Barrio  edad     Género  \
# 0                                            NaN     0   FEMENINO
# 1                                            NaN     0   FEMENINO
# 2                                            NaN     0  MASCULINO
# 3                                            NaN     0  MASCULINO
# 4                                            NaN     0   FEMENINO
# ...                                          ...   ...        ...
# 151403                                       NaN   102  MASCULINO
# 151404       CENTRO                                125   FEMENINO
# 151405                                       NaN   125   FEMENINO
# 151406                                       NaN   125   FEMENINO
# 151407  SAN RAFAEL                                 125   FEMENINO
#
#                                                     etnia  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404  Mestiza                                       ...
# 151405                                                NaN
# 151406                                                NaN
# 151407                     Afrocolombiana
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                          No Aplica
# 151405                                                NaN
# 151406                                                NaN
# 151407  Desplazado                                    ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 2       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       PISCINA POLIDEPORTIVO SUR                     ...  ...
# ...                                                   ...  ...
# 151403  PLACA PARQUE RECREATIVO                       ...  ...
# 151404  PISCINA PARQUE RECREATIVO                     ...  ...
# 151405  PARQUE RECREATIVO                             ...  ...
# 151406  PISCINA LAS COMETAS                           ...  ...
# 151407  LUDOTECA LA MINA                              ...  ...
#
#                                    eps  estrato  \
# 0                                  NaN      NaN
# 1                                  NaN      NaN
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 151403                             NaN      NaN
# 151404  Nueva EPS S.A.                        2
# 151405  Sura EPS                            NaN
# 151406                             NaN      NaN
# 151407  SAVIA SALUD EPS                       1
#
#                        Municipio_residencia  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 151403                                  NaN
# 151404  ENVIGADO
# 151405                                  NaN
# 151406                                  NaN
# 151407  ENVIGADO
#
#                                   tipo_documento  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 151403                                       NaN
# 151404  Cédula de Ciudadanía
# 151405  Cédula de Ciudadanía
# 151406  Registro Civil
# 151407  Cédula de Ciudadanía
#
#                                       nacimiento     rh  \
# 0                                            NaN    NaN
# 1                                            NaN    NaN
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 151403                                       NaN    NaN
# 151404  CISNEROS                                  A-
# 151405                                       NaN    NaN
# 151406                                       NaN    NaN
# 151407                                       NaN  O+
#
#                                              nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                                NaN
# 151405                                                NaN
# 151406                                                NaN
# 151407  COLOMBIA                                      ...
#
#                                      escolaridad diversidad  \
# 0                                            NaN  No Aplica
# 1                                            NaN  No Aplica
# 2                                            NaN  No Aplica
# 3                                            NaN  No Aplica
# 4                                            NaN  No Aplica
# ...                                          ...        ...
# 151403                                       NaN  No Aplica
# 151404  BÁSICA SECUNDARIA                         No Aplica
# 151405                                       NaN  No Aplica
# 151406                                       NaN  No Aplica
# 151407  BÁSICA PRIMARIA                           No Aplica
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 3       MUNICIPIO DE ENVIGADO 100%                    ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 151403  MUSICOTERAPIA-                                ...
# 151404  NO APLICA                                     ...
# 151405  NO APLICA                                     ...
# 151406  SISBEN 2                                      ...
# 151407  PP                                            ...
#
# [151408 rows x 24 columns]

# %%
## transformar el tipo de dato en algunas columnas.

INSCRITOSIE = INSCRITOSIE.astype({'Nro_inscripcion': 'int32'})

# Convertir la columna 'Servicio' a texto en mayúsculas
INSCRITOSIE['Disciplina'] = INSCRITOSIE['Disciplina'].str.upper()

INSCRITOSIE['Nivel'] = INSCRITOSIE['Nivel'].astype('category')

INSCRITOSIE = INSCRITOSIE.astype({'Barrio': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'edad': 'int32'})

INSCRITOSIE = INSCRITOSIE.astype({'Género': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'etnia': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Poblacion': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Escenario': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'instructor': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'curso': 'int32'})

INSCRITOSIE = INSCRITOSIE.astype({'zona': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'eps': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'estrato': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Municipio_residencia': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'tipo_documento': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'nacimiento': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'rh': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'nacionalidad': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'escolaridad': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'diversidad': 'category'})

INSCRITOSIE = INSCRITOSIE.astype({'Población': 'category'})

# %%
INSCRITOSIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151408 entries, 0 to 151407
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   fecha                 151408 non-null  datetime64[ns]
#  1   Nro_inscripcion       151408 non-null  int32
#  2   Disciplina            151408 non-null  object
#  3   Nivel                 151408 non-null  category
#  4   Barrio                129840 non-null  category
#  5   edad                  151408 non-null  int32
#  6   Género                151408 non-null  category
#  7   etnia                 136262 non-null  category
#  8   Poblacion             136199 non-null  category
#  9   Escenario             151408 non-null  category
#  10  instructor            151408 non-null  category
#  11  curso                 151408 non-null  int32
#  12  zona                  124283 non-null  category
#  13  fecha_nacimiento      146469 non-null  datetime64[ns]
#  14  eps                   131043 non-null  category
#  15  estrato               133757 non-null  category
#  16  Municipio_residencia  130842 non-null  category
#  17  tipo_documento        132268 non-null  category
#  18  nacimiento            31741 non-null   category
#  19  rh                    133837 non-null  category
#  20  nacionalidad          122129 non-null  category
#  21  escolaridad           132028 non-null  category
#  22  diversidad            150205 non-null  category
#  23  Población             151408 non-null  category
# dtypes: category(18), datetime64[ns](2), int32(3), object(1)
# memory usage: 8.8+ MB

# %%
# El metodo replace Identifica el valor a buscar y luego reemplaza en todos los campos con el valor deseado.
INSCRITOSIE = INSCRITOSIE.replace("", None)
INSCRITOSIE
# Out:
#             fecha  Nro_inscripcion  \
# 0      2018-01-17            89537
# 1      2018-01-17            89531
# 2      2018-01-18            89556
# 3      2018-01-18            89584
# 4      2018-01-18            89685
# ...           ...              ...
# 151403 2020-01-28            45315
# 151404 2021-04-12            47115
# 151405 2022-01-20            50017
# 151406 2022-03-31             2487
# 151407 2023-04-25            47850
#
#                                                Disciplina  \
# 0                                       GIMNASIA INFANTIL
# 1                                                NATACIÓN
# 2                                                NATACIÓN
# 3                                                NATACIÓN
# 4                                                NATACIÓN
# ...                                                   ...
# 151403  MUSICOTERAPIA                                 ...
# 151404  HIDROAERÓBICOS                                ...
# 151405  HIDROAERÓBICOS                                ...
# 151406                               NATACIÓN LAS COMETAS
# 151407  PP ZONA 6
#
#                                                     Nivel  \
# 0       INICIACIÓN 2 (8-12)                           ...
# 1       CALAMARES                                     ...
# 2       III (6-8) AÑOS                                ...
# 3       I ADULTOS                                     ...
# 4       FORMATIVO AVANZADO ADULTOS                    ...
# ...                                                   ...
# 151403  INSCRIPCIÓN                                   ...
# 151404  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151405  INSCRIPCIÓN QUINCE SESIONES                   ...
# 151406  CALAMARES                                     ...
# 151407  LUDOTECA                                      ...
#
#                                           Barrio  edad     Género  \
# 0                                            NaN     0   FEMENINO
# 1                                            NaN     0   FEMENINO
# 2                                            NaN     0  MASCULINO
# 3                                            NaN     0  MASCULINO
# 4                                            NaN     0   FEMENINO
# ...                                          ...   ...        ...
# 151403                                       NaN   102  MASCULINO
# 151404       CENTRO                                125   FEMENINO
# 151405                                       NaN   125   FEMENINO
# 151406                                       NaN   125   FEMENINO
# 151407  SAN RAFAEL                                 125   FEMENINO
#
#                                                     etnia  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404  Mestiza                                       ...
# 151405                                                NaN
# 151406                                                NaN
# 151407                     Afrocolombiana
#
#                                                 Poblacion  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                          No Aplica
# 151405                                                NaN
# 151406                                                NaN
# 151407  Desplazado                                    ...
#
#                                                 Escenario  ...  \
# 0       SALON DE GIMNASIA INFANTIL POLIDEPORTIVO      ...  ...
# 1       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 2       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 3       PISCINA POLIDEPORTIVO SUR                     ...  ...
# 4       PISCINA POLIDEPORTIVO SUR                     ...  ...
# ...                                                   ...  ...
# 151403  PLACA PARQUE RECREATIVO                       ...  ...
# 151404  PISCINA PARQUE RECREATIVO                     ...  ...
# 151405  PARQUE RECREATIVO                             ...  ...
# 151406  PISCINA LAS COMETAS                           ...  ...
# 151407  LUDOTECA LA MINA                              ...  ...
#
#                                    eps  estrato  \
# 0                                  NaN      NaN
# 1                                  NaN      NaN
# 2                                  NaN      NaN
# 3                                  NaN      NaN
# 4                                  NaN      NaN
# ...                                ...      ...
# 151403                             NaN      NaN
# 151404  Nueva EPS S.A.                        2
# 151405  Sura EPS                            NaN
# 151406                             NaN      NaN
# 151407  SAVIA SALUD EPS                       1
#
#                        Municipio_residencia  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 151403                                  NaN
# 151404  ENVIGADO
# 151405                                  NaN
# 151406                                  NaN
# 151407  ENVIGADO
#
#                                   tipo_documento  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 151403                                       NaN
# 151404  Cédula de Ciudadanía
# 151405  Cédula de Ciudadanía
# 151406  Registro Civil
# 151407  Cédula de Ciudadanía
#
#                                       nacimiento     rh  \
# 0                                            NaN    NaN
# 1                                            NaN    NaN
# 2                                            NaN    NaN
# 3                                            NaN    NaN
# 4                                            NaN    NaN
# ...                                          ...    ...
# 151403                                       NaN    NaN
# 151404  CISNEROS                                  A-
# 151405                                       NaN    NaN
# 151406                                       NaN    NaN
# 151407                                       NaN  O+
#
#                                              nacionalidad  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151403                                                NaN
# 151404                                                NaN
# 151405                                                NaN
# 151406                                                NaN
# 151407  COLOMBIA                                      ...
#
#                                      escolaridad diversidad  \
# 0                                            NaN  No Aplica
# 1                                            NaN  No Aplica
# 2                                            NaN  No Aplica
# 3                                            NaN  No Aplica
# 4                                            NaN  No Aplica
# ...                                          ...        ...
# 151403                                       NaN  No Aplica
# 151404  BÁSICA SECUNDARIA                         No Aplica
# 151405                                       NaN  No Aplica
# 151406                                       NaN  No Aplica
# 151407  BÁSICA PRIMARIA                           No Aplica
#
#                                                 Población
# 0       NO APLICA                                     ...
# 1       NO APLICA                                     ...
# 2       INCAPACIDAD DE PAGO Y/O CONVENIO 50%          ...
# 3       MUNICIPIO DE ENVIGADO 100%                    ...
# 4       NO APLICA                                     ...
# ...                                                   ...
# 151403  MUSICOTERAPIA-                                ...
# 151404  NO APLICA                                     ...
# 151405  NO APLICA                                     ...
# 151406  SISBEN 2                                      ...
# 151407  PP                                            ...
#
# [151408 rows x 24 columns]

# %%
## creo una copia del DF original, para posteriormente modificarlo
INSCRITOSIE_2 = INSCRITOSIE

# %%
# Reemplazar los valores nulos por None y No APLICA por OTRO
INSCRITOSIE['Barrio'] = INSCRITOSIE['Barrio'].replace({'NULL': None})
INSCRITOSIE['Barrio'] = INSCRITOSIE['Barrio'].replace({'NO APLICA': 'OTRO'})

# %%
##INSCRITOSIE.dop(columns=['nacimiento'],inplace=true)
##INSCRITOSE

# %%
# Limpiamos columnas de texto eliminando espacios innecesarios y convertimos primeras letras de una palabra a mayúsculas
def limpiar_texto(texto):
    if isinstance(texto, str):  # Verificamos que el valor sea string
        return ' '.join(texto.strip().title().split())  # Elimina espacios innecesarios y convierte el formato
    return texto  # Si no es texto, se devuelve el valor original sin cambios

# Lista de columnas de texto que se van a limpiar
columnas_texto = ['fecha', 'Nro_inscripcion', 'Disciplina', 'Nivel', 'Barrio', 'edad',
                   'Género', 'etnia', 'Poblacion', 'Escenario', 'instructor',
                   'curso', 'zona', 'fecha_nacimiento', 'eps',
                   'estrato', 'Municipio_residencia', 'tipo_documento','nacimiento', 'rh','nacionalidad', 'escolaridad','diversidad','Población' ]

# Aplicación de la función de limpieza a las columnas de texto
INSCRITOSIE[columnas_texto] = INSCRITOSIE[columnas_texto].applymap(limpiar_texto)
# Out:
# <ipython-input-79-5b906a5b79d1>:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   INSCRITOSIE[columnas_texto] = INSCRITOSIE[columnas_texto].applymap(limpiar_texto)

# %%
INSCRITOSIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151408 entries, 0 to 151407
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   fecha                 151408 non-null  datetime64[ns]
#  1   Nro_inscripcion       151408 non-null  int64
#  2   Disciplina            151408 non-null  object
#  3   Nivel                 151408 non-null  object
#  4   Barrio                129840 non-null  category
#  5   edad                  151408 non-null  int64
#  6   Género                151408 non-null  category
#  7   etnia                 136262 non-null  category
#  8   Poblacion             136199 non-null  category
#  9   Escenario             151408 non-null  object
#  10  instructor            151408 non-null  object
#  11  curso                 151408 non-null  int64
#  12  zona                  124283 non-null  object
#  13  fecha_nacimiento      146469 non-null  datetime64[ns]
#  14  eps                   131043 non-null  object
#  15  estrato               133757 non-null  category
#  16  Municipio_residencia  130842 non-null  object
#  17  tipo_documento        132268 non-null  category
#  18  nacimiento            31741 non-null   object
#  19  rh                    133837 non-null  object
#  20  nacionalidad          122129 non-null  object
#  21  escolaridad           132028 non-null  object
#  22  diversidad            150205 non-null  category
#  23  Población             151408 non-null  category
# dtypes: category(8), datetime64[ns](2), int64(3), object(11)
# memory usage: 19.6+ MB

# %%
INSCRITOSIE
# Out:
#             fecha  Nro_inscripcion            Disciplina  \
# 0      2018-01-17            89537     Gimnasia Infantil
# 1      2018-01-17            89531              Natación
# 2      2018-01-18            89556              Natación
# 3      2018-01-18            89584              Natación
# 4      2018-01-18            89685              Natación
# ...           ...              ...                   ...
# 151403 2020-01-28            45315         Musicoterapia
# 151404 2021-04-12            47115        Hidroaeróbicos
# 151405 2022-01-20            50017        Hidroaeróbicos
# 151406 2022-03-31             2487  Natación Las Cometas
# 151407 2023-04-25            47850             Pp Zona 6
#
#                               Nivel      Barrio  edad     Género  \
# 0               Iniciación 2 (8-12)         NaN     0   Femenino
# 1                         Calamares         NaN     0   Femenino
# 2                    Iii (6-8) Años         NaN     0  Masculino
# 3                         I Adultos         NaN     0  Masculino
# 4        Formativo Avanzado Adultos         NaN     0   Femenino
# ...                             ...         ...   ...        ...
# 151403                  Inscripción         NaN   102  Masculino
# 151404  Inscripción Quince Sesiones      Centro   125   Femenino
# 151405  Inscripción Quince Sesiones         NaN   125   Femenino
# 151406                    Calamares         NaN   125   Femenino
# 151407                     Ludoteca  San Rafael   125   Femenino
#
#                  etnia   Poblacion                                 Escenario  \
# 0                  NaN         NaN  Salon De Gimnasia Infantil Polideportivo
# 1                  NaN         NaN                 Piscina Polideportivo Sur
# 2                  NaN         NaN                 Piscina Polideportivo Sur
# 3                  NaN         NaN                 Piscina Polideportivo Sur
# 4                  NaN         NaN                 Piscina Polideportivo Sur
# ...                ...         ...                                       ...
# 151403             NaN         NaN                   Placa Parque Recreativo
# 151404         Mestiza   No Aplica                 Piscina Parque Recreativo
# 151405             NaN         NaN                         Parque Recreativo
# 151406             NaN         NaN                       Piscina Las Cometas
# 151407  Afrocolombiana  Desplazado                          Ludoteca La Mina
#
#         ...              eps  estrato Municipio_residencia  \
# 0       ...              NaN      NaN                  NaN
# 1       ...              NaN      NaN                  NaN
# 2       ...              NaN      NaN                  NaN
# 3       ...              NaN      NaN                  NaN
# 4       ...              NaN      NaN                  NaN
# ...     ...              ...      ...                  ...
# 151403  ...              NaN      NaN                  NaN
# 151404  ...   Nueva Eps S.A.        2             Envigado
# 151405  ...         Sura Eps      NaN                  NaN
# 151406  ...              NaN      NaN                  NaN
# 151407  ...  Savia Salud Eps        1             Envigado
#
#               tipo_documento nacimiento   rh nacionalidad        escolaridad  \
# 0                        NaN        NaN  NaN          NaN                NaN
# 1                        NaN        NaN  NaN          NaN                NaN
# 2                        NaN        NaN  NaN          NaN                NaN
# 3                        NaN        NaN  NaN          NaN                NaN
# 4                        NaN        NaN  NaN          NaN                NaN
# ...                      ...        ...  ...          ...                ...
# 151403                   NaN        NaN  NaN          NaN                NaN
# 151404  Cédula De Ciudadanía   Cisneros   A-          NaN  Básica Secundaria
# 151405  Cédula De Ciudadanía        NaN  NaN          NaN                NaN
# 151406        Registro Civil        NaN  NaN          NaN                NaN
# 151407  Cédula De Ciudadanía        NaN   O+     Colombia    Básica Primaria
#
#        diversidad                             Población
# 0       No Aplica                             No Aplica
# 1       No Aplica                             No Aplica
# 2       No Aplica  Incapacidad De Pago Y/O Convenio 50%
# 3       No Aplica            Municipio De Envigado 100%
# 4       No Aplica                             No Aplica
# ...           ...                                   ...
# 151403  No Aplica                        Musicoterapia-
# 151404  No Aplica                             No Aplica
# 151405  No Aplica                             No Aplica
# 151406  No Aplica                              Sisben 2
# 151407  No Aplica                                    Pp
#
# [151408 rows x 24 columns]

# %%
# verificar valores únicos en Barrio
print(INSCRITOSIE['Barrio'].unique())
# Out:
# [NaN, 'La Paz', 'La Mina', 'Loma De Las Brujas', 'San Rafael', ..., 'El Esmeraldal', 'Vereda El Escobero', 'Bosques De Zuñiga', 'Villagrande', 'Vereda Santa Catalina']
# Length: 48
# Categories (47, object): ['Alcalá', 'Alto De Misael', 'Bosques De Zuñiga', 'Bucarest', ...,
#                           'Vereda Perico', 'Vereda Santa Catalina', 'Villagrande', 'Zuñiga']

# %%
## buscar duplicados en el dataframe
INSCRITOSIE.duplicated().sum()
# Out:
# np.int64(12)

# %%
import numpy as np

# Verificar si la edad es menor o igual a cero y reemplazarla por NaN
INSCRITOSIE.loc[INSCRITOSIE['edad'] <= 0, 'edad'] = np.nan

# %%
# Verificar si la edad es mayor a 100 años y reemplazarla por NaN
INSCRITOSIE.loc[INSCRITOSIE['edad'] > 100, 'edad'] = np.nan

# %%
INSCRITOSIE
# Out:
#             fecha  Nro_inscripcion            Disciplina  \
# 0      2018-01-17            89537     Gimnasia Infantil
# 1      2018-01-17            89531              Natación
# 2      2018-01-18            89556              Natación
# 3      2018-01-18            89584              Natación
# 4      2018-01-18            89685              Natación
# ...           ...              ...                   ...
# 151403 2020-01-28            45315         Musicoterapia
# 151404 2021-04-12            47115        Hidroaeróbicos
# 151405 2022-01-20            50017        Hidroaeróbicos
# 151406 2022-03-31             2487  Natación Las Cometas
# 151407 2023-04-25            47850             Pp Zona 6
#
#                               Nivel      Barrio  edad     Género  \
# 0               Iniciación 2 (8-12)         NaN   NaN   Femenino
# 1                         Calamares         NaN   NaN   Femenino
# 2                    Iii (6-8) Años         NaN   NaN  Masculino
# 3                         I Adultos         NaN   NaN  Masculino
# 4        Formativo Avanzado Adultos         NaN   NaN   Femenino
# ...                             ...         ...   ...        ...
# 151403                  Inscripción         NaN   NaN  Masculino
# 151404  Inscripción Quince Sesiones      Centro   NaN   Femenino
# 151405  Inscripción Quince Sesiones         NaN   NaN   Femenino
# 151406                    Calamares         NaN   NaN   Femenino
# 151407                     Ludoteca  San Rafael   NaN   Femenino
#
#                  etnia   Poblacion                                 Escenario  \
# 0                  NaN         NaN  Salon De Gimnasia Infantil Polideportivo
# 1                  NaN         NaN                 Piscina Polideportivo Sur
# 2                  NaN         NaN                 Piscina Polideportivo Sur
# 3                  NaN         NaN                 Piscina Polideportivo Sur
# 4                  NaN         NaN                 Piscina Polideportivo Sur
# ...                ...         ...                                       ...
# 151403             NaN         NaN                   Placa Parque Recreativo
# 151404         Mestiza   No Aplica                 Piscina Parque Recreativo
# 151405             NaN         NaN                         Parque Recreativo
# 151406             NaN         NaN                       Piscina Las Cometas
# 151407  Afrocolombiana  Desplazado                          Ludoteca La Mina
#
#         ...              eps  estrato Municipio_residencia  \
# 0       ...              NaN      NaN                  NaN
# 1       ...              NaN      NaN                  NaN
# 2       ...              NaN      NaN                  NaN
# 3       ...              NaN      NaN                  NaN
# 4       ...              NaN      NaN                  NaN
# ...     ...              ...      ...                  ...
# 151403  ...              NaN      NaN                  NaN
# 151404  ...   Nueva Eps S.A.        2             Envigado
# 151405  ...         Sura Eps      NaN                  NaN
# 151406  ...              NaN      NaN                  NaN
# 151407  ...  Savia Salud Eps        1             Envigado
#
#               tipo_documento nacimiento   rh nacionalidad        escolaridad  \
# 0                        NaN        NaN  NaN          NaN                NaN
# 1                        NaN        NaN  NaN          NaN                NaN
# 2                        NaN        NaN  NaN          NaN                NaN
# 3                        NaN        NaN  NaN          NaN                NaN
# 4                        NaN        NaN  NaN          NaN                NaN
# ...                      ...        ...  ...          ...                ...
# 151403                   NaN        NaN  NaN          NaN                NaN
# 151404  Cédula De Ciudadanía   Cisneros   A-          NaN  Básica Secundaria
# 151405  Cédula De Ciudadanía        NaN  NaN          NaN                NaN
# 151406        Registro Civil        NaN  NaN          NaN                NaN
# 151407  Cédula De Ciudadanía        NaN   O+     Colombia    Básica Primaria
#
#        diversidad                             Población
# 0       No Aplica                             No Aplica
# 1       No Aplica                             No Aplica
# 2       No Aplica  Incapacidad De Pago Y/O Convenio 50%
# 3       No Aplica            Municipio De Envigado 100%
# 4       No Aplica                             No Aplica
# ...           ...                                   ...
# 151403  No Aplica                        Musicoterapia-
# 151404  No Aplica                             No Aplica
# 151405  No Aplica                             No Aplica
# 151406  No Aplica                              Sisben 2
# 151407  No Aplica                                    Pp
#
# [151408 rows x 24 columns]

# %%
print(INSCRITOSIE['edad'].isna().sum())  # Para contar cuántos NaN hay en la columna 'edad'
# Out:
# 4957
